# %% [markdown]
# # Notebook 01: Exploratory Data Analysis & Loading
#
# This notebook demonstrates how to load the synthetic CPG sales dataset directly into Databricks using PySpark.

# %%
# %pip install -e ../

# %%
from src.data_loader import DataLoader
import os

# Since we are running on Databricks Community Edition, we ensure PySpark is True
dl = DataLoader(use_spark=True)

# Load data from DBFS or Catalog
# df = dl.load_data('dbfs:/FileStore/tables/cpg_sales_data.parquet')
# For now, we simulate a pandas conversion to view the schema easily:
print("DataLoader initialized correctly!")
