# %% [markdown]
# # Notebook 03: Scenario Simulation
#
# Testing the 'What-If' simulation tools for price hikes and category promotions.

# %%
import pandas as pd
from src.tools.scenario_simulation import simulate_price_change, simulate_promotion

# Sample Data
data = {
    'date': ['2022-01-01', '2022-01-02', '2022-01-03'],
    'sku_id': [101, 101, 102],
    'category': ['Beverages', 'Beverages', 'Snacks'],
    'units_sold': [100, 150, 200],
    'revenue': [500, 750, 800],
    'price': [5.0, 5.0, 4.0],
    'promo_flag': [0, 0, 0]
}
df = pd.DataFrame(data)

print("Price Simulation (10% hike on sku 101):")
print(simulate_price_change(df, sku_id=101, price_change_pct=0.1, elasticity=-1.5))

print("\nPromotion Simulation (20% volume uplift on Beverages):")
print(simulate_promotion(df, category='Beverages', promo_uplift_pct=0.2, promo_cost_per_unit=1.0))
